# %%
1.# linke lists:non contagious ds
2.# memory allocate
3'''
4.single linked list
5.double linked list
6.circular s/d linked list
7.'''
# 1.single linked list
# head---> node1---> node2--->tail/null
'''
class node:
  def__init__(self,data):
    self.data=data
    self.next=None
class linkedlist:
  def__init__(self):
    self.head=None
'''

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None
class LinkedList:
  def __init__(self):
    self.head=None
  def iap(self,data,pos):
    if pos<0:
      print("Position min>=1")
      return

    new_node=Node(data)
    if pos==1:
      new_node.next==self.head
      self.head=new_node
      print(f"{data} insearted at pos-1.")
      return
    current=self.head
    c=1
    while current and c < pos-1:
      current=current.next
      c+=1
    if not current:
      print("Not in range")
      return
    new_node.next=current.next
    current.next=new_node


  def display(self):
    current = self.head
    if not current:
      print("LL-Empty")
      return
    while current:
      print(current.data, end='---')
      current=current.next
    print("None")


ll=LinkedList()
while True:
  print("\n LinkedList- Insert At Ending....")
  print("1. inseart")
  print("2. display")
  print("3. Exit")
  choice=input("Enter your choice:")
  if choice=="1":
    data=int(input("Enter a value to inseart:"))
    pos=int(input("enter positon starting from 1:"))
    ll.iap(data,pos)
  elif choice=="2":
    ll.display()
  elif choice=="3":
    break
  else:
    print("Invalied choice")
# Out:
#  LinkedList- Insert At Ending....
# 1. inseart
# 2. display
# 3. Exit
# Enter your choice:1
# Enter a value to inseart:50
# enter positon starting from 1:1
# 50 insearted at pos-1.
#
#  LinkedList- Insert At Ending....
# 1. inseart
# 2. display
# 3. Exit
# Enter your choice:1
# Enter a value to inseart:60
# enter positon starting from 1:2
#
#  LinkedList- Insert At Ending....
# 1. inseart
# 2. display
# 3. Exit
# Enter your choice:1
# Enter a value to inseart:40
# enter positon starting from 1:3
#
#  LinkedList- Insert At Ending....
# 1. inseart
# 2. display
# 3. Exit
# Enter your choice:2
# 50---60---40---None
#
#  LinkedList- Insert At Ending....
# 1. inseart
# 2. display
# 3. Exit
# Enter your choice:3

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def iae(self, data):
    new_node = Node(data)
    if self.head is None:
      self.head = new_node
      print(f"{data} inserted at end/ will be first node.")
      return
    current = self.head
    while current.next:
      current = current.next
    current.next = new_node
    print(f"{data} inserted last.")

  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Ending.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iae(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 45
# 45 inserted at end/ will be first node.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 56
# 56 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 87
# 87 inserted last.
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 45-->56-->87-->None
#
#  LinkedList - Insert at Ending.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exit the operation...

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None
  def iab(self, data):
    new_node = Node(data)
    new_node.next = self.head
    self.head = new_node
    print(f"{data} inserted from begin.")
  def display(self):
    current = self.head
    if not current:
      print("List is empty")
      return
    while current:
      print(current.data, end="-->")
      current= current.next
    print("None")

ll=LinkedList()
while True:
  print("\n LinkedList - Insert at Begin.....")
  print("1. insert ")
  print("2. Display")
  print("3. Exit")
  choice= input("Enter your choice: ")
  if choice == '1':
    data = int(input("Enter a value to insert: "))
    ll.iab(data)
  elif choice=='2':
    ll.display()
  elif choice=='3':
    print("Exit the operation...")
    break
  else:
    print("Enter only .... 1/2/3")
# Out:
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 50
# 50 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 40
# 40 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 30
# 30 inserted from begin.
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# 30-->40-->50-->None
#
#  LinkedList - Insert at Begin.....
# 1. insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exit the operation...

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None
class LinkedList:
  def __init__(self):
    self.head=None
  def iap(self,data,pos):
    if pos<0:
      print("Position min>=1")
      return

    new_node=Node(data)
    if pos==1:
      new_node.next==self.head
      self.head=new_node
      print(f"{data} insearted at pos-1.")
      return
    current=self.head
    c=1
    while current and c < pos-1:
      current=current.next
      c+=1
    if not current:
      print("Not in range")
      return
    new_node.next=current.next
    current.next=new_node


  def display(self):
    current = self.head
    if not current:
      print("LL-Empty")
      return
    while current:
      print(current.data, end='---')
      current=current.next
    print("None")


ll=LinkedList()
while True:
  print("\n LinkedList- Insert At Ending....")
  print("1. inseart")
  print("2. display")
  print("3. Exit")
  choice=input("Enter your choice:")
  if choice=="1":
    data=int(input("Enter a value to inseart:"))
    pos=int(input("enter positon starting from 1:"))
    ll.iap(data,pos)
  elif choice=="2":
    ll.display()
  elif choice=="3":
    break
  else:
    print("Invalied choice")
